# %% [markdown]
# # getting-started-with-text-embeddings

# %% [markdown]
# ![image.png](attachment:fe1dfb4b-5fee-41aa-a062-27e9aaa43a28.png)

# %% [markdown]
# ![image.png](attachment:272c39c5-d385-4f0e-b4d4-4f40db0fafb4.png)

# %% [markdown]
# ![image.png](attachment:efe17c58-1659-40d0-84c1-cd1beba2d6e7.png)

# %% [markdown]
# ![image.png](attachment:fbe441be-197a-4ea0-be48-6d6314f9b0bb.png)

# %% [markdown]
# ![image.png](attachment:887bdd6e-a871-48f5-9d8d-2780488a8aee.png)

# %%
#!pip install google-cloud-aiplatform
#https://console.cloud.google.com/welcome?project=round-gamma-245717

# %%
import vertexai

# %%
# Import and initialize the Vertex AI Python SDK
import vertexai
REGION = 'us-central1'
PROJECT_ID = 'round-gamma-245717'
vertexai.init(project = PROJECT_ID, 
              location = REGION, 
              credentials = credentials)

# %%
from vertexai.language_models import TextEmbeddingModel

# %%
embedding_model = TextEmbeddingModel.from_pretrained("textembedding-gecko@001")
embedding_model

# %%
embedding = embedding_model.get_embeddings(["life"])

# %%
vector = embedding[0].values
print(f"Length = {len(vector)}")
print(vector[:10])
